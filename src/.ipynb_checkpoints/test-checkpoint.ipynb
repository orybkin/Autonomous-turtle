# %%
from utils.map_registrator import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
pc1=np.load('data/pc_30.npy')
pc1.shape
# Out:
# (480, 640, 3)

# %%
X=pc1.transpose((2,1,0)).reshape((3,-1))
fig=plt.figure()
ax = fig.add_subplot(111, projection='3d')
subsam=20
ax.scatter(X[2,::subsam],X[0,::subsam],X[1,::subsam],s=1)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
import numpy as np
import cv2
import time
from math import *
from numpy.linalg import pinv


X=np.random.rand(3,10)
normal=np.array([[1, 1, 1]])
print normal.T.dot(normal)
X=X-normal * normal.dot(X)

fig=plt.figure()
ax = fig.add_subplot(111, projection='3d')
subsam=20
ax.scatter(X[2,::subsam],X[0,::subsam],X[1,::subsam],s=1)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# [[1 1 1]
#  [1 1 1]
#  [1 1 1]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b5a21fd90f3b> in <module>()
#       9 normal=np.array([[1, 1, 1]])
#      10 print normal.T.dot(normal)
# ---> 11 X=X-normal * normal.dot(X)
#      12
#      13 fig=plt.figure()
#
# ValueError: operands could not be broadcast together with shapes (1,3) (1,10)
